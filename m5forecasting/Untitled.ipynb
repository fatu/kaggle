# %% [markdown]
# # Basline 思路解析
#     a. 时序数据转换为面板数据(动态回归模型)
#     b. 标签分布和损失函数的关系(评估函数和损失函数)
#     c. 预测后的处理
#         c.1 乘以扩大系数
#         c.2 迭代预测

# %% [markdown]
# ### 时间序列的基本知识
#     a. 时间序列的基本性质
#     b. 经典模型(模型分类，规则，STL分解，ETS，ARIMA，SARIMA)

# %% [markdown]
# ### 层次时间序列
#     a. 什么是层次时间序列
#     b. 如何解决层次时间序列

# %% [markdown]
# ### Prophet 模型
#     a. 基本原理
#     b. 代码

# %% [markdown]
# ### LGB 模型
# ### 特征工程的一般套路
#     a. 时序特征工程的一般套路
#     b. tsfresh 官方文档
# ### DARNN 论文解析
#     深度学习处理时间序列

# %% [markdown]
# # 赛题 Trick启发

# %% [markdown]
# ![Screen Shot 2020-05-25 at 4.26.32 PM.png](attachment:182ebd93-327d-4908-9186-e551c1b731b3.png)

# %% [markdown]
# 鲁棒性更重要，尽量不要翻车
